# %%
'''

map_water_assets.py

    This script creates mapping between the JEM nodal file and the nismod.jamaica.water 
    sector assets. Specifically, it links each energy-consumptive water asset to the nearest
    utility pole or substation in the energy sector nodal file. 
    

'''

import geopandas as gpd
from shapely.ops import nearest_points
from tqdm import tqdm

print('loading data...')
elec_nodes = gpd.read_file('../data/spatial/infrasim-network/nodes.shp')
water_nodes = gpd.read_file('../data/water/merged_water_assets.shp')
print('done')

output_col_name = 'id'
water_id = 'node_id'

# index nodes
gpd1 = elec_nodes.loc[elec_nodes.subtype.isin(['pole','substation'])].reset_index(drop=True).copy()
gpd2 = water_nodes.loc[water_nodes.linkage == 'True'].reset_index(drop=True).copy()
# form unary union
pts3 = gpd1.geometry.unary_union
# init elec_asset column
gpd2[output_col_name] = ''
# loop through each water asset
print('looping across water nodes to map energy assets...')
for i, row in gpd2.iterrows():
    nearest_elec_asset = nearest_points(row.geometry, pts3)[1]
    gpd2.loc[i,output_col_name] = gpd1.loc[gpd1.geometry.within(nearest_elec_asset),'id'].values[0]
# append water nodes
water_nodes[output_col_name] = water_nodes[water_id].map(\
                gpd2.set_index(water_id)[output_col_name].to_dict())
print('done')

# save to shapefile
print('saving file...')
water_nodes.to_file(driver='ESRI Shapefile',filename='../data/water/mapped_water_assets.shp')
# save to csv
water_nodes[[water_id,output_col_name]].to_csv('../data/water/mapped_water_assets.shp',index=False)
print('done')
print('files saved to: ../data/water/mapped_water_assets.shp')
# Out:
# /Users/amanmajid/opt/anaconda3/envs/jem_model/lib/python3.7/site-packages/geopandas/_compat.py:58: UserWarning: The installed version of PyGEOS is too old (0.6 installed, 0.8 required), and thus GeoPandas will not use PyGEOS.
#   UserWarning,
# loading data...
# done
# looping across water nodes to map energy assets...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ff/h_ytkqld47vg92jnpfrrfx5w0000gn/T/ipykernel_84879/1864903622.py in <module>
#      36 # append water nodes
#      37 water_nodes[output_col_name] = water_nodes[water_id].map(\
# ---> 38                 gpd2[[water_id,output_col_name]].set_index(water_id[output_col_name].to_dict()))
#      39 print('done')
#      40
#
# TypeError: string indices must be integers

# %%
# Out:
# {'well_0.0': 'node_29888',
#  'well_1.0056497175141244': 'node_32659',
#  'well_2.0112994350282487': 'node_32615',
#  'well_3.016949152542373': 'node_32660',
#  'well_4.022598870056497': 'node_31040',
#  'well_5.028248587570622': 'node_41111',
#  'well_6.033898305084746': 'node_41111',
#  'well_7.03954802259887': 'node_3005',
#  'well_8.045197740112995': 'node_32632',
#  'well_9.05084745762712': 'node_32649',
#  'well_10.056497175141244': 'node_30687',
#  'well_11.062146892655369': 'node_30681',
#  'well_12.067796610169491': 'node_30691',
#  'well_13.073446327683616': 'node_219',
#  'well_14.07909604519774': 'node_2583',
#  'well_15.084745762711865': 'node_4052',
#  'well_16.09039548022599': 'node_4060',
#  'well_17.096045197740114': 'node_623',
#  'well_18.10169491525424': 'node_2480',
#  'well_19.107344632768363': 'node_3005',
#  'well_20.112994350282488': 'node_3005',
#  'well_21.118644067796613': 'node_3005',
#  'well_22.124293785310737': 'node_3900',
#  'well_23.12994350282486': 'node_1515',
#  'well_24.135593220338983': 'node_3368',
#  'well_25.141242937853107': 'node_2599',
#  'well_26.146892655367232': 'node_3356',
#  'well_27.152542372881356': 'node_3357',
#  'well_28.15819209039548': 'node_9569',
#  'well_29.163841807909606': 'node_4286',
#  'well_30.16949152542373': 'node_564',
#  'well_31.175141242937855': 'node_460',
#  'well_32.18079096045198': 'node_350',
#  'well_33.186440677966104': 'node_2563',
#  'well_34.19209039548023': 'node_2571',
#  'well_35.19774011299435': 'node_152',
#  'well_36.20338983050848': 'node_1516',
#  'well_37.2090395480226': 'node_2460',
#  'well_38.21468926553673': 'node_2462',
#  'well_39.22033898305085': 'node_3003',
#  'well_40.225988700564976': 'node_7706',
#  'well_41.2316384180791': 'node_7706',
#  'well_42.237288135593225': 'node_7702',
#  'well_43.24293785310735': 'node_7708',
#  'well_44.248587570621474': 'node_269',
#  'well_45.2542372881356': 'node_7714',
#  'well_46.25988700564972': 'node_268',
#  'well_47.26553672316385': 'node_728',
#  'well_48.271186440677965': 'node_282',
#  'well_49.27683615819209': 'node_9569',
#  'well_50.282485875706215': 'node_550',
#  'well_51.28813559322034': 'node_3356',
#  'well_52.293785310734464': 'node_7714',
#  'well_53.29943502824859': 'node_7706',
#  'well_54.30508474576271': 'node_272',
#  'well_55.31073446327684': 'node_8076',
#  'well_56.31638418079096': 'node_7488',
#  'well_57.32203389830509': 'node_7488',
#  'well_58.32768361581921': 'node_7831',
#  'well_59.333333333333336': 'node_9899',
#  'well_60.33898305084746': 'node_29072',
#  'well_61.344632768361585': 'node_22543',
#  'well_62.35028248587571': 'node_29072',
#  'well_63.355932203389834': 'node_24418',
#  'well_64.36158192090396': 'node_22598',
#  'well_65.36723163841808': 'node_25997',
#  'well_66.37288135593221': 'node_26108',
#  'well_67.37853107344633': 'node_25778',
#  'well_68.38418079096046': 'node_25807',
#  'well_69.38983050847457': 'node_22598',
#  'well_70.3954802259887': 'node_23503',
#  'well_71.40112994350282': 'node_27820',
#  'well_72.40677966101696': 'node_26390',
#  'well_73.41242937853107': 'node_26390',
#  'well_74.4180790960452': 'node_25776',
#  'well_75.42372881355932': 'node_25776',
#  'well_76.42937853107345': 'node_22190',
#  'well_77.43502824858757': 'node_26962',
#  'well_78.4406779661017': 'node_27090',
#  'well_79.44632768361582': 'node_26909',
#  'well_80.45197740112995': 'node_26902',
#  'well_81.45762711864407': 'node_1332',
#  'well_82.4632768361582': 'node_1332',
#  'well_83.46892655367232': 'node_1332',
#  'well_84.47457627118645': 'node_23678',
#  'well_85.48022598870057': 'node_23748',
#  'well_86.4858757062147': 'node_27574',
#  'well_87.49152542372882': 'node_28513',
#  'well_88.49717514124295': 'node_23764',
#  'well_89.50282485875707': 'node_25115',
#  'well_90.5084745762712': 'node_29888',
#  'well_91.51412429378531': 'node_39282',
#  'well_92.51977401129945': 'node_39671',
#  'well_93.52542372881356': 'node_39450',
#  'well_94.5310734463277': 'node_38988',
#  'well_95.53672316384181': 'node_1332',
#  'well_96.54237288135593': 'node_1332',
#  'well_97.54802259887006': 'node_1332',
#  'well_98.55367231638418': 'node_23678',
#  'well_99.55932203389831': 'node_23748',
#  'well_100.56497175141243': 'node_27574',
#  'well_101.57062146892656': 'node_28513',
#  'well_102.57627118644068': 'node_23764',
#  'well_103.58192090395481': 'node_25115',
#  'well_104.58757062146893': 'node_29888',
#  'well_105.59322033898306': 'node_1544',
#  'well_106.59887005649718': 'node_4003',
#  'well_107.60451977401131': 'node_3282',
#  'well_108.61016949152543': 'node_3910',
#  'well_109.61581920903956': 'node_3566',
#  'well_110.62146892655367': 'node_1479',
#  'well_111.6271186440678': 'node_3908',
#  'well_112.63276836158192': 'node_3908',
#  'well_113.63841807909606': 'node_1479',
#  'well_114.64406779661017': 'node_3290',
#  'well_115.6497175141243': 'node_3290',
#  'well_116.65536723163842': 'node_644',
#  'well_117.66101694915255': 'node_3125',
#  'well_118.66666666666667': 'node_1479',
#  'well_119.6723163841808': 'node_1473',
#  'well_120.67796610169492': 'node_692',
#  'well_121.68361581920905': 'node_3908',
#  'well_122.68926553672317': 'node_4005',
#  'well_123.6949152542373': 'node_3908',
#  'well_124.70056497175142': 'node_1742',
#  'well_125.70621468926555': 'node_1742',
#  'well_126.71186440677967': 'node_3908',
#  'well_127.7175141242938': 'node_4312',
#  'well_128.72316384180792': 'node_670',
#  'well_129.72881355932205': 'node_4218',
#  'well_130.73446327683615': 'node_617',
#  'well_131.74011299435028': 'node_1748',
#  'well_132.74576271186442': 'node_670',
#  'well_133.75141242937855': 'node_4312',
#  'well_134.75706214689265': 'node_1742',
#  'well_135.76271186440678': 'node_3908',
#  'well_136.7683615819209': 'node_3140',
#  'well_137.77401129943505': 'node_670',
#  'well_138.77966101694915': 'node_3908',
#  'well_139.78531073446328': 'node_3113',
#  'well_140.7909604519774': 'node_3130',
#  'well_141.79661016949154': 'node_682',
#  'well_142.80225988700565': 'node_3130',
#  'well_143.80790960451978': 'node_3132',
#  'well_144.8135593220339': 'node_1754',
#  'well_145.81920903954804': 'node_675',
#  'well_146.82485875706215': 'node_683',
#  'well_147.83050847457628': 'node_673',
#  'well_148.8361581920904': 'node_670',
#  'well_149.84180790960454': 'node_670',
#  'well_150.84745762711864': 'node_3465',
#  'well_151.85310734463278': 'node_3465',
#  'well_152.8587570621469': 'node_3465',
#  'well_153.86440677966104': 'node_2165',
#  'well_154.87005649717514': 'node_712',
#  'well_155.87570621468927': 'node_555',
#  'well_156.8813559322034': 'node_3446',
#  'well_157.88700564971754': 'node_3485',
#  'well_158.89265536723164': 'node_711',
#  'well_159.89830508474577': 'node_711',
#  'well_160.9039548022599': 'node_3480',
#  'well_161.909604519774': 'node_3480',
#  'well_162.91525423728814': 'node_3480',
#  'well_163.92090395480227': 'node_3480',
#  'well_164.9265536723164': 'node_588',
#  'well_165.9322033898305': 'node_566',
#  'well_166.93785310734464': 'node_591',
#  'well_167.94350282485877': 'node_588',
#  'well_168.9491525423729': 'node_3447',
#  'well_169.954802259887': 'node_3211',
#  'well_170.96045197740114': 'node_711',
#  'well_171.96610169491527': 'node_711',
#  'well_172.9717514124294': 'node_711',
#  'well_173.9774011299435': 'node_3436',
#  'well_174.98305084745763': 'node_3211',
#  'well_175.98870056497177': 'node_712',
#  'well_176.9943502824859': 'node_3542',
#  'well_178.0': 'node_43688',
#  'Spring_5.0': 'node_40928',
#  'Storage Tank_6.0': 'node_21453',
#  'Storage Tank_7.0': 'node_39928',
#  'Storage Tank_8.0': 'node_40924',
#  'Storage Tank_9.0': 'node_39928',
#  'Storage Tank_10.0': 'node_39854',
#  'Storage Tank_11.0': 'node_40444',
#  'Storage Tank_12.0': 'node_40311',
#  'Storage Tank_13.0': 'node_40537',
#  'Storage Tank_14.0': 'node_40539',
#  'Storage Tank_15.0': 'node_40322',
#  'Storage Tank_16.0': 'node_39864',
#  'Storage Tank_17.0': 'node_39929',
#  'Storage Tank_18.0': 'node_39857',
#  'Storage Tank_19.0': 'node_40442',
#  'Storage Tank_20.0': 'node_40304',
#  'Storage Tank_21.0': 'node_39849',
#  'Storage Tank_22.0': 'node_40837',
#  'Storage Tank_23.0': 'node_40440',
#  'Storage Tank_24.0': 'node_40434',
#  'Storage Tank_25.0': 'node_39910',
#  'Storage Tank_26.0': 'node_39871',
#  'Storage Tank_27.0': 'node_39929',
#  'Storage Tank_28.0': 'node_39929',
#  'Storage Tank_29.0': 'node_41069',
#  'Storage Tank_30.0': 'node_39906',
#  'Storage Tank_31.0': 'node_39893',
#  'Storage Tank_32.0': 'node_40338',
#  'Storage Tank_33.0': 'node_38308',
#  'Storage Tank_34.0': 'node_37012',
#  'Spring_35.0': 'node_37012',
#  'Storage Tank_36.0': 'node_37033',
#  'Spring_37.0': 'node_37191',
#  'Spring_38.0': 'node_37974',
#  'Storage Tank_39.0': 'node_36779',
#  'Storage Tank_40.0': 'node_36783',
#  'Storage Tank_41.0': 'node_38019',
#  'Storage Tank_42.0': 'node_38019',
#  'Storage Tank_43.0': 'node_37998',
#  'Storage Tank_44.0': 'node_27238',
#  'Storage Tank_45.0': 'node_36544',
#  'Spring_46.0': 'node_22520',
#  'Storage Tank_47.0': 'node_37554',
#  'Storage Tank_48.0': 'node_37222',
#  'Storage Tank_49.0': 'node_36962',
#  'Storage Tank_50.0': 'node_36705',
#  'Storage Tank_51.0': 'node_37530',
#  'Spring_52.0': 'node_37004',
#  'Storage Tank_53.0': 'node_40476',
#  'Storage Tank_54.0': 'node_40574',
#  'Storage Tank_55.0': 'node_40575',
#  'Storage Tank_56.0': 'node_40625',
#  'Storage Tank_57.0': 'node_40587',
#  'Storage Tank_59.0': 'node_20556',
#  'Storage Tank_64.0': 'node_18787',
#  'Storage Tank_69.0': 'node_19055',
#  'Storage Tank_71.0': 'node_21928',
#  'Storage Tank_73.0': 'node_20415',
#  'Storage Tank_74.0': 'node_20494',
#  'Storage Tank_77.0': 'node_20139',
#  'Storage Tank_78.0': 'node_20138',
#  'Storage Tank_79.0': 'node_19079',
#  'Storage Tank_80.0': 'node_19058',
#  'Storage Tank_81.0': 'node_19051',
#  'Storage Tank_85.0': 'node_21940',
#  'Storage Tank_86.0': 'node_21399',
#  'Storage Tank_87.0': 'node_20351',
#  'Storage Tank_91.0': 'node_21156',
#  'Storage Tank_95.0': 'node_21980',
#  'Storage Tank_97.0': 'node_20118',
#  'Storage Tank_99.0': 'node_19505',
#  'Storage Tank_101.0': 'node_20016',
#  'Storage Tank_107.0': 'node_19775',
#  'Storage Tank_108.0': 'node_19776',
#  'Storage Tank_109.0': 'node_19595',
#  'Storage Tank_111.0': 'node_19593',
#  'Storage Tank_114.0': 'node_19568',
#  'Storage Tank_115.0': 'node_20195',
#  'Storage Tank_119.0': 'node_19650',
#  'Storage Tank_122.0': 'node_20222',
#  'Storage Tank_124.0': 'node_19725',
#  'Storage Tank_127.0': 'node_19764',
#  'Storage Tank_129.0': 'node_19791',
#  'Storage Tank_131.0': 'node_18448',
#  'Storage Tank_132.0': 'node_19589',
#  'Storage Tank_133.0': 'node_20826',
#  'Storage Tank_137.0': 'node_19999',
#  'Storage Tank_140.0': 'node_20550',
#  'Storage Tank_141.0': 'node_19460',
#  'Storage Tank_142.0': 'node_35474',
#  'Spring_143.0': 'node_36255',
#  'Spring_144.0': 'node_35596',
#  'Spring_145.0': 'node_34024',
#  'Storage Tank_146.0': 'node_33992',
#  'Storage Tank_147.0': 'node_33267',
#  'Storage Tank_148.0': 'node_33292',
#  'Storage Tank_149.0': 'node_33416',
#  'Spring_150.0': 'node_33428',
#  'Spring_151.0': 'node_35813',
#  'Storage Tank_152.0': 'node_33810',
#  'Filter Plant_153.0': 'node_1353',
#  'Storage Tank_154.0': 'node_1353',
#  'River Source_155.0': 'node_3858',
#  'Production Well_156.0': 'node_3537',
#  'Storage Tank_157.0': 'node_180',
#  'Storage Tank_158.0': 'node_180',
#  'Sump_159.0': 'node_1805',
#  'Pump Station_160.0': 'node_1067',
#  'Storage Tank_161.0': 'node_2892',
#  'Storage Tank_162.0': 'node_2892',
#  'Storage Tank_163.0': 'node_2892',
#  'Production Well_164.0': 'node_2517',
#  'Entombment_165.0': 'node_2344',
#  'Entombment_166.0': 'node_1872',
#  'Filter Plant_167.0': 'node_1872',
#  'Storage Tank_168.0': 'node_3797',
#  'Filter Plant_169.0': 'node_3793',
#  'Storage Tank_170.0': 'node_126',
#  'Storage Tank_171.0': 'node_2940',
#  'Storage Tank_172.0': 'node_205',
#  'Pump Station_173.0': 'node_180',
#  'Production Well_174.0': 'node_1473',
#  'Storage Tank_175.0': 'node_4009',
#  'Storage Tank_176.0': 'node_3182',
#  'Storage Tank_177.0': 'node_1592',
#  'Storage Tank_178.0': 'node_1845',
#  'Storage Tank_179.0': 'node_1570',
#  'Storage Tank_180.0': 'node_2958',
#  'Storage Tank_181.0': 'node_159',
#  'Relift Station_182.0': 'node_1406',
#  'Entombment_183.0': 'node_1406',
#  'Relift Station_184.0': 'node_3942',
#  'Filter Plant_185.0': 'node_3942',
#  'Storage Tank_186.0': 'node_2145',
#  'Production Well_187.0': 'node_222',
#  'Storage Tank_188.0': 'node_2579',
#  'Production Well_189.0': 'node_327',
#  'Storage Tank_190.0': 'node_327',
#  'Production Well_191.0': 'node_2968',
#  'Storage Tank_192.0': 'node_2968',
#  'Relift Station_193.0': 'node_2968',
#  'Relift Station_194.0': 'node_2571',
#  'Storage Tank_195.0': 'node_4296',
#  'Production Well_196.0': 'node_3900',
#  'Relift Station_197.0': 'node_3900',
#  'Production Well_198.0': 'node_3398',
#  'Storage Tank_199.0': 'node_3398',
#  'Relift Station_200.0': 'node_3398',
#  'Filter Plant_201.0': 'node_2397',
#  'Production Well_202.0': 'node_1776',
#  'Production Well_203.0': 'node_3431',
#  'Production Well_204.0': 'node_3204',
#  'Production Well_205.0': 'node_564',
#  'Production Well_206.0': 'node_3474',
#  'Production Well_207.0': 'node_3474',
#  'Production Well_208.0': 'node_3280',
#  'Production Well_209.0': 'node_1507',
#  'Production Well_210.0': 'node_1104',
#  'Production Well_211.0': 'node_2799',
#  'Production Well_212.0': 'node_974',
#  'Production Well_213.0': 'node_4107',
#  'Production Well_214.0': 'node_2635',
#  'Production Well_215.0': 'node_979',
#  'Production Well_216.0': 'node_605',
#  'Production Well_217.0': 'node_611',
#  'Production Well_218.0': 'node_3066',
#  'Production Well_219.0': 'node_2015',
#  'Production Well_220.0': 'node_1279',
#  'Storage Tank_221.0': 'node_1279',
#  'Production Well_222.0': 'node_1235',
#  'Production Well_223.0': 'node_238',
#  'Production Well_224.0': 'node_1570',
#  'Production Well_225.0': 'node_1013',
#  'Production Well_226.0': 'node_1013',
#  'Production Well_227.0': 'node_2271',
#  'Relift Station_228.0': 'node_2870',
#  'Relift Station_229.0': 'node_2209',
#  'Storage Tank_230.0': 'node_2190',
#  'Storage Tank_231.0': 'node_803',
#  'Relift Station_232.0': 'node_793',
#  'Storage Tank_233.0': 'node_3857',
#  'Storage Tank_234.0': 'node_1003',
#  'Pump Station_235.0': 'node_18442',
#  'Storage Tank_236.0': 'node_37796',
#  'Storage Tank_237.0': 'node_37255',
#  'Storage Tank_238.0': 'node_36560',
#  'Treatment Plant_240.0': 'node_37337',
#  'Storage Tank_242.0': 'node_37363',
#  'Storage Tank_243.0': 'node_37151',
#  'Pump Station_244.0': 'node_20771',
#  'Pump Station_246.0': 'node_37212',
#  'Pump Station_247.0': 'node_38152',
#  'Pump Station_248.0': 'node_38155',
#  'Spring_249.0': 'node_38155',
#  'Treatment Plant_250.0': 'node_37204',
#  'Storage Tank_251.0': 'node_38001',
#  'Filter Plant_252.0': 'node_37856',
#  'Pump Station_253.0': 'node_36974',
#  'Relift Station_254.0': 'node_38022',
#  'Storage Tank_255.0': 'node_37066',
#  'Storage Tank_256.0': 'node_37087',
#  'Relift Station_257.0': 'node_37660',
#  'Reservoir_258.0': 'node_38105',
#  'Spring_259.0': 'node_37462',
#  'Pump Station_260.0': 'node_37157',
#  'Entombment_261.0': 'node_37120',
#  'Spring_262.0': 'node_37120',
#  'Treatment Plant_263.0': 'node_20420',
#  'Relift Station_264.0': 'node_20421',
#  'Storage Tank_265.0': 'node_37516',
#  'Relift Station_266.0': 'node_37280',
#  'Storage Tank_267.0': 'node_36881',
#  'Relift Station_268.0': 'node_36844',
#  'Relift Station_269.0': 'node_36980',
#  'Storage Tank_270.0': 'node_36982',
#  'Storage Tank_271.0': 'node_36982',
#  'Relift Station_272.0': 'node_38187',
#  'Storage Tank_273.0': 'node_38237',
#  'Relift Station_274.0': 'node_38241',
#  'Storage Tank_275.0': 'node_38166',
#  'Storage Tank_276.0': 'node_38164',
#  'Pump Station_277.0': 'node_38245',
#  'Storage Tank_278.0': 'node_36995',
#  'Treatment Plant_279.0': 'node_38519',
#  'Storage Tank_280.0': 'node_38521',
#  'Relift Station_281.0': 'node_36625',
#  'Reservoir_282.0': 'node_37421',
#  'Relift Station_283.0': 'node_38125',
#  'Storage Tank_284.0': 'node_38129',
#  'Treatment Plant_285.0': 'node_38428',
#  'Relift Station_286.0': 'node_37522',
#  'Storage Tank_287.0': 'node_36550',
#  'Pump Station_289.0': 'node_37337',
#  'Storage Tank_290.0': 'node_38909',
#  'Storage Tank_293.0': 'node_39468',
#  'Pump Station_295.0': 'node_39086',
#  'Storage Tank_297.0': 'node_39086',
#  'Intake_298.0': 'node_39085',
#  'Reservoir_299.0': 'node_39500',
#  'Production Well_300.0': 'node_10263',
#  'Production Well_301.0': 'node_10263',
#  'Production Well_302.0': 'node_61',
#  'Storage Tank_303.0': 'node_61',
#  'Production Well_304.0': 'node_39582',
#  'Production Well_305.0': 'node_39582',
#  'Booster Station_306.0': 'node_39582',
#  'Storage Tank_307.0': 'node_39037',
#  'Storage Tank_308.0': 'node_38847',
#  'Production Well_309.0': 'node_38626',
#  'Pump Station_310.0': 'node_39372',
#  'Filter Plant_311.0': 'node_39698',
#  'Storage Tank_312.0': 'node_39698',
#  'Filter Plant_313.0': 'node_39091',
#  'Filter Plant_314.0': 'node_39143',
#  'Pump Station_315.0': 'node_39147',
#  'Pump Station_317.0': 'node_39482',
#  'Storage Tank_318.0': 'node_39511',
#  'Storage Tank_319.0': 'node_39145',
#  'Pump Station_320.0': 'node_39577',
#  'Pump Station_321.0': 'node_38584',
#  'Pump Station_322.0': 'node_38797',
#  'Pump Station_323.0': 'node_38634',
#  'Storage Tank_324.0': 'node_38793',
#  'Pump Station_325.0': 'node_38793',
#  'Pump Station_326.0': 'node_38656',
#  'Storage Tank_327.0': 'node_38728',
#  'Storage Tank_328.0': 'node_38663',
#  'Pump Station_329.0': 'node_38663',
#  'Storage Tank_330.0': 'node_38669',
#  'Storage Tank_331.0': 'node_39072',
#  'Relift Station_332.0': 'node_38862',
#  'Pump Station_333.0': 'node_38536',
#  'Storage Tank_334.0': 'node_39412',
#  'Storage Tank_335.0': 'node_39412',
#  'Pump Station_337.0': 'node_39386',
#  'Pump Station_338.0': 'node_39683',
#  'Pump Station_339.0': 'node_39125',
#  'Storage Tank_340.0': 'node_39097',
#  'Pump Station_341.0': 'node_39429',
#  'Pump Station_342.0': 'node_39560',
#  'Pump Station_343.0': 'node_39801',
#  'Pump Station_344.0': 'node_39669',
#  'Pump Station_345.0': 'node_39385',
#  'Storage Tank_346.0': 'node_39080',
#  'Pump Station_347.0': 'node_39080',
#  'Entombment_348.0': 'node_38967',
#  'Pump Station_349.0': 'node_39145',
#  'Filter Plant_350.0': 'node_39451',
#  'Storage Tank_354.0': 'node_39150',
#  'Relift Station_355.0': 'node_38934',
#  'Relift Station_356.0': 'node_38934',
#  'Relift Station_358.0': 'node_39760',
#  'Filter Plant_359.0': 'node_39760',
#  'Production Well_360.0': 'node_38628',
#  'Intake_362.0': 'node_39757',
#  'Intake_363.0': 'node_39757',
#  'Relift Station_364.0': 'node_38841',
#  'Treatment Plant_365.0': 'node_25711',
#  'Reservoir_366.0': 'node_23915',
#  'Storage Tank_367.0': 'node_29972',
#  'Storage Tank_368.0': 'node_22053',
#  'Treatment Plant_369.0': 'node_26890',
#  'Storage Tank_370.0': 'node_26886',
#  'Treatment Plant_371.0': 'node_21280',
#  'Pump Station_372.0': 'node_21933',
#  'Pump Station_373.0': 'node_24922',
#  'Booster Station_374.0': 'node_27305',
#  'Booster Station_375.0': 'node_27731',
#  'Storage Tank_376.0': 'node_26430',
#  'Booster Station_377.0': 'node_25602',
#  'Booster Station_378.0': 'node_25529',
#  'Storage Tank_379.0': 'node_28438',
#  'Relift Station_380.0': 'node_25084',
#  'Reservoir_381.0': 'node_25084',
#  'Relift Station_382.0': 'node_24932',
#  'Relift Station_383.0': 'node_24605',
#  'Storage Tank_384.0': 'node_24605',
#  'Relift Station_385.0': 'node_22388',
#  'Relift Station_386.0': 'node_23915',
#  'Storage Tank_387.0': 'node_23915',
#  'Booster Station_388.0': 'node_24174',
#  'Treatment Plant_389.0': 'node_29996',
#  'Filter Plant_390.0': 'node_28489',
#  'Intake_391.0': 'node_28489',
#  'Storage Tank_392.0': 'node_24744',
#  'Booster Station_393.0': 'node_24744',
#  'Storage Tank_394.0': 'node_28507',
#  'Booster Station_395.0': 'node_22262',
#  'Booster Station_396.0': 'node_22463',
#  'Booster Station_397.0': 'node_25518',
#  'Sump_398.0': 'node_25518',
#  'Booster Station_399.0': 'node_24726',
#  'Sump_400.0': 'node_24726',
#  'Booster Station_401.0': 'node_25621',
#  'Production Well_402.0': 'node_25115',
#  'Production Well_403.0': 'node_23135',
#  'Production Well_404.0': 'node_24530',
#  'Production Well_405.0': 'node_29990',
#  'Production Well_406.0': 'node_27301',
#  'Production Well_407.0': 'node_23654',
#  'Production Well_408.0': 'node_23503',
#  'Production Well_409.0': 'node_26913',
#  'Production Well_410.0': 'node_26903',
#  'Production Well_411.0': 'node_22812',
#  'Production Well_412.0': 'node_22812',
#  'Production Well_413.0': 'node_29072',
#  'Production Well_414.0': 'node_29929',
#  'Production Well_415.0': 'node_26897',
#  'Production Well_416.0': 'node_22822',
#  'Production Well_417.0': 'node_23004',
#  'Pump Station_418.0': 'node_22869',
#  'Production Well_419.0': 'node_25795',
#  'Production Well_420.0': 'node_23417',
#  'Production Well_421.0': 'node_24289',
#  'Production Well_422.0': 'node_26758',
#  'Treatment Plant_423.0': 'node_21932',
#  'Production Well_424.0': 'node_28365',
#  'Production Well_425.0': 'node_18861',
#  'Production Well_426.0': 'node_26248',
#  'Production Well_427.0': 'node_25294',
#  'Production Well_428.0': 'node_22510',
#  'Production Well_429.0': 'node_22510',
#  'Production Well_430.0': 'node_22410',
#  'Production Well_431.0': 'node_22509',
#  'Relift Station_432.0': 'node_25685',
#  'Relift Station_433.0': 'node_28418',
#  'Production Well_434.0': 'node_28883',
#  'Production Well_435.0': 'node_28741',
#  'Production Well_436.0': 'node_28701',
#  'Production Well_437.0': 'node_29457',
#  'Production Well_438.0': 'node_29479',
#  'Production Well_439.0': 'node_24360',
#  'Production Well_440.0': 'node_24710',
#  'Production Well_441.0': 'node_24604',
#  'Storage Tank_442.0': 'node_25076',
#  'Treatment Plant_443.0': 'node_27816',
#  'Storage Tank_444.0': 'node_27606',
#  'Storage Tank_445.0': 'node_27606',
#  'Relift Station_446.0': 'node_27581',
#  'Storage Tank_447.0': 'node_28184',
#  'Storage Tank_448.0': 'node_29834',
#  'Booster Station_449.0': 'node_22272',
#  'Booster Station_450.0': 'node_22271',
#  'Storage Tank_451.0': 'node_24362',
#  'Storage Tank_452.0': 'node_29751',
#  'Storage Tank_453.0': 'node_29009',
#  'Booster Station_454.0': 'node_29092',
#  'Treatment Plant_455.0': 'node_28753',
#  'Storage Tank_457.0': 'node_1083',
#  'Relift Station_458.0': 'node_1083',
#  'Treatment Plant_459.0': 'node_1083',
#  'Pump Station_460.0': 'node_3989',
#  'Storage Tank_461.0': 'node_21539',
#  'Storage Tank_462.0': 'node_21541',
#  'Pump Station_463.0': 'node_40374',
#  'Spring_464.0': 'node_19683',
#  'Storage Tank_465.0': 'node_19683',
#  'Storage Tank_466.0': 'node_19715',
#  'Treatment Plant_467.0': 'node_22024',
#  'Pump Station_468.0': 'node_20050',
#  'Storage Tank_469.0': 'node_20066',
#  'Pump Station_470.0': 'node_20066',
#  'Pump Station_471.0': 'node_19898',
#  'Production Well_472.0': 'node_20624',
#  'Storage Tank_473.0': 'node_19516',
#  'Production Well_474.0': 'node_19695',
#  'Storage Tank_475.0': 'node_19695',
#  'Relift Station_476.0': 'node_19782',
#  'Storage Tank_477.0': 'node_19782',
#  'Storage Tank_478.0': 'node_19739',
#  'Storage Tank_479.0': 'node_20076',
#  'Spring_480.0': 'node_20539',
#  'Spring_481.0': 'node_21141',
#  'Spring_482.0': 'node_18671',
#  'Storage Tank_483.0': 'node_18675',
#  'Spring_484.0': 'node_21075',
#  'Spring_485.0': 'node_20556',
#  'Storage Tank_486.0': 'node_21507',
#  'Storage Tank_487.0': 'node_21507',
#  'Storage Tank_488.0': 'node_21294',
#  'Relift Station_489.0': 'node_20992',
#  'Spring_490.0': 'node_21390',
#  'Spring_491.0': 'node_20346',
#  'Storage Tank_492.0': 'node_20351',
#  'Storage Tank_493.0': 'node_20346',
#  'Spring_494.0': 'node_20361',
#  'Relift Station_495.0': 'node_20361',
#  'Storage Tank_496.0': 'node_20360',
#  'Storage Tank_497.0': 'node_18932',
#  'Spring_498.0': 'node_19050',
#  'Production Well_499.0': 'node_20510',
#  'Production Well_500.0': 'node_18726',
#  'Storage Tank_501.0': 'node_18726',
#  'Storage Tank_502.0': 'node_20777',
#  'Production Well_503.0': 'node_18994',
#  'Storage Tank_504.0': 'node_18994',
#  'Storage Tank_505.0': 'node_19068',
#  'Spring_506.0': 'node_19068',
#  'Storage Tank_507.0': 'node_18675',
#  'Relift Station_508.0': 'node_18675',
#  'Spring_509.0': 'node_19054',
#  'Storage Tank_510.0': 'node_18602',
#  'Spring_511.0': 'node_21922',
#  'Storage Tank_512.0': 'node_20143',
#  'Storage Tank_513.0': 'node_18602',
#  'Storage Tank_514.0': 'node_18602',
#  'Storage Tank_515.0': 'node_19094',
#  'Spring_516.0': 'node_19094',
#  'Pump Station_517.0': 'node_20982',
#  'Pump Station_518.0': 'node_19280',
#  'Storage Tank_519.0': 'node_19280',
#  'Pump Station_520.0': 'node_20794',
#  'Spring_521.0': 'node_20794',
#  'Storage Tank_522.0': 'node_20794',
#  'Pump Station_523.0': 'node_20790',
#  'Spring_524.0': 'node_20484',
#  'Relift Station_525.0': 'node_21232',
#  'Relift Station_526.0': 'node_20924',
#  'Storage Tank_527.0': 'node_20447',
#  'Storage Tank_528.0': 'node_20392',
#  'Pump Station_529.0': 'node_20392',
#  'Pump Station_530.0': 'node_20426',
#  'Spring_531.0': 'node_20325',
#  'Spring_532.0': 'node_20642',
#  'Production Well_533.0': 'node_20605',
#  'Relift Station_534.0': 'node_19417',
#  'Storage Tank_535.0': 'node_19417',
#  'Relift Station_536.0': 'node_19412',
#  'Storage Tank_537.0': 'node_19412',
#  'Storage Tank_538.0': 'node_20629',
#  'Spring_539.0': 'node_21074',
#  'Storage Tank_540.0': 'node_18650',
#  'Storage Tank_541.0': 'node_21524',
#  'Spring_542.0': 'node_18608',
#  'Production Well_543.0': 'node_19186',
#  'Storage Tank_544.0': 'node_19186',
#  'Storage Tank_545.0': 'node_21464',
#  'Storage Tank_546.0': 'node_18572',
#  'Storage Tank_547.0': 'node_18583',
#  'Storage Tank_548.0': 'node_18578',
#  'Pump Station_549.0': 'node_18562',
#  'Storage Tank_550.0': 'node_18576',
#  'Storage Tank_551.0': 'node_18576',
#  'Treatment Plant_552.0': 'node_18853',
#  'Storage Tank_553.0': 'node_18879',
#  'Treatment Plant_554.0': 'node_18681',
#  'Reservoir_555.0': 'node_18681',
#  'Pump Station_556.0': 'node_18681',
#  'Storage Tank_557.0': 'node_19265',
#  'River Source_558.0': 'node_19361',
#  'Storage Tank_559.0': 'node_21102',
#  'Storage Tank_560.0': 'node_43145',
#  'Relift Station_561.0': 'node_41435',
#  'Relift Station_562.0': 'node_42519',
#  'Reservoir_563.0': 'node_42501',
#  'Storage Tank_564.0': 'node_41435',
#  'Entombment_565.0': 'node_41569',
#  'Entombment_566.0': 'node_41425',
#  'Pump Station_567.0': 'node_41425',
#  'Entombment_568.0': 'node_43111',
#  'Pump Station_569.0': 'node_43111',
#  'Pump Station_570.0': 'node_42558',
#  'Production Well_571.0': 'node_43032',
#  'Storage Tank_572.0': 'node_42662',
#  'Pump Station_573.0': 'node_42641',
#  'Storage Tank_574.0': 'node_41431',
#  'Spring_575.0': 'node_43142',
#  'Relift Station_576.0': 'node_41724',
#  'Reservoir_577.0': 'node_42214',
#  'Reservoir_578.0': 'node_42835',
#  'Booster Station_579.0': 'node_42864',
#  'Pump Station_580.0': 'node_41754',
#  'Production Well_581.0': 'node_41776',
#  'Booster Station_582.0': 'node_41976',
#  'Pump Station_583.0': 'node_41529',
#  'Storage Tank_584.0': 'node_42006',
#  'Treatment Plant_585.0': 'node_42027',
#  'Storage Tank_586.0': 'node_5177',
#  'Pump Station_587.0': 'node_5177',
#  'Pump Station_588.0': 'node_43148',
#  'Storage Tank_589.0': 'node_43148',
#  'Storage Tank_590.0': 'node_41336',
#  'Pump Station_591.0': 'node_41339',
#  'Pump Station_592.0': 'node_41519',
#  'Treatment Plant_593.0': 'node_41296',
#  'Treatment Plant_594.0': 'node_41296',
#  'Storage Tank_595.0': 'node_41296',
#  'Treatment Plant_596.0': 'node_22030',
#  'Storage Tank_597.0': 'node_19388',
#  'Intake_598.0': 'node_40115',
#  'Treatment Plant_599.0': 'node_40056',
#  'Storage Tank_600.0': 'node_40023',
#  'Relift Station_601.0': 'node_40016',
#  'Storage Tank_602.0': 'node_40470',
#  'Storage Tank_603.0': 'node_41088',
#  'Pump Station_604.0': 'node_41088',
#  'Pump Station_605.0': 'node_41168',
#  'Pump Station_606.0': 'node_41090',
#  'Storage Tank_607.0': 'node_40106',
#  'Storage Tank_608.0': 'node_40007',
#  'Production Well_609.0': 'node_41099',
#  'Storage Tank_610.0': 'node_40986',
#  'Storage Tank_611.0': 'node_40986',
#  'Storage Tank_612.0': 'node_40986',
#  'Pump Station_613.0': 'node_40952',
#  'Production Well_614.0': 'node_40625',
#  'Pump Station_615.0': 'node_40661',
#  'Pump Station_616.0': 'node_40403',
#  'Storage Tank_617.0': 'node_40405',
#  'Storage Tank_619.0': 'node_40357',
#  'Pump Station_620.0': 'node_40683',
#  'Storage Tank_621.0': 'node_40678',
#  'Storage Tank_622.0': 'node_41117',
#  'Storage Tank_623.0': 'node_40789',
#  'Storage Tank_624.0': 'node_40789',
#  'Storage Tank_625.0': 'node_40735',
#  'Pump Station_626.0': 'node_39959',
#  'Storage Tank_627.0': 'node_40573',
#  'Pump Station_628.0': 'node_40570',
#  'Storage Tank_629.0': 'node_41093',
#  'Storage Tank_630.0': 'node_40876',
#  'Storage Tank_631.0': 'node_40154',
#  'Pump Station_632.0': 'node_35357',
#  'Pump Station_633.0': 'node_39916',
#  'Pump Station_634.0': 'node_39895',
#  'Storage Tank_635.0': 'node_39876',
#  'Storage Tank_636.0': 'node_39901',
#  'Storage Tank_637.0': 'node_39869',
#  'Pump Station_638.0': 'node_39848',
#  'Storage Tank_640.0': 'node_40546',
#  'Storage Tank_641.0': 'node_40832',
#  'Storage Tank_643.0': 'node_39915',
#  'Pump Station_644.0': 'node_39915',
#  'Storage Tank_645.0': 'node_39851',
#  'Pump Station_646.0': 'node_39873',
#  'Storage Tank_647.0': 'node_39873',
#  'Filter Plant_648.0': 'node_39884',
#  'Storage Tank_649.0': 'node_39921',
#  'Production Well_650.0': 'node_41143',
#  'Pump Station_651.0': 'node_41143',
#  'Production Well_652.0': 'node_41005',
#  'Production Well_653.0': 'node_40146',
#  'Production Well_654.0': 'node_40147',
#  'Relift Station_655.0': 'node_40243',
#  'Storage Tank_656.0': 'node_40243',
#  'Reservoir_657.0': 'node_41140',
#  'Booster Station_658.0': 'node_40191',
#  'Storage Tank_659.0': 'node_40846',
#  'Treatment Plant_660.0': 'node_39982',
#  'Intake_661.0': 'node_39984',
#  'Storage Tank_662.0': 'node_30827',
#  'Storage Tank_663.0': 'node_31467',
#  'Storage Tank_664.0': 'node_31790',
#  'Storage Tank_665.0': 'node_30514',
#  'Storage Tank_666.0': 'node_7605',
#  'River Source_667.0': 'node_7605',
#  'Production Well_668.0': 'node_9898',
#  'Production Well_669.0': 'node_9898',
#  'Storage Tank_670.0': 'node_9898',
#  'Storage Tank_671.0': 'node_9898',
#  'Relift Station_672.0': 'node_30583',
#  'Storage Tank_673.0': 'node_30583',
#  'Storage Tank_674.0': 'node_30214',
#  'Storage Tank_675.0': 'node_30238',
#  'Relift Station_676.0': 'node_30214',
#  'Storage Tank_677.0': 'node_7461',
#  'Storage Tank_678.0': 'node_7751',
#  'Storage Tank_679.0': 'node_30547',
#  'Storage Tank_680.0': 'node_30217',
#  'Production Well_681.0': 'node_30195',
#  'River Source_682.0': 'node_30186',
#  'River Source_683.0': 'node_30246',
#  'Production Well_684.0': 'node_32321',
#  'Spring_685.0': 'node_32321',
#  'Storage Tank_686.0': 'node_30176',
#  'Spring_687.0': 'node_30261',
#  'Storage Tank_688.0': 'node_30587',
#  'Production Well_689.0': 'node_30146',
#  'Storage Tank_690.0': 'node_30147',
#  'Booster Station_691.0': 'node_32258',
#  'Production Well_692.0': 'node_30673',
#  'Pump Station_693.0': 'node_30029',
#  'Pump Station_694.0': 'node_31315',
#  'Storage Tank_695.0': 'node_30314',
#  'Production Well_696.0': 'node_32352',
#  'Spring_697.0': 'node_32093',
#  'Storage Tank_698.0': 'node_32234',
#  'Production Well_699.0': 'node_32146',
#  'Storage Tank_700.0': 'node_32146',
#  'Storage Tank_701.0': 'node_32146',
#  'Production Well_702.0': 'node_8351',
#  'Storage Tank_703.0': 'node_8351',
#  'Storage Tank_704.0': 'node_8351',
#  'Production Well_705.0': 'node_30683',
#  'Production Well_706.0': 'node_30683',
#  'Pump Station_707.0': 'node_30683',
#  'Production Well_708.0': 'node_30700',
#  'Storage Tank_709.0': 'node_30700',
#  'Production Well_710.0': 'node_32598',
#  'Reservoir_711.0': 'node_32658',
#  'Storage Tank_712.0': 'node_32601',
#  'Relift Station_713.0': 'node_31226',
#  'Storage Tank_714.0': 'node_31226',
#  'Production Well_715.0': 'node_32609',
#  'Relift Station_716.0': 'node_32166',
#  'Relift Station_717.0': 'node_31952',
#  'Storage Tank_718.0': 'node_31089',
#  'Storage Tank_719.0': 'node_32673',
#  'Production Well_720.0': 'node_32114',
#  'Pump Station_721.0': 'node_31666',
#  'Storage Tank_722.0': 'node_31666',
#  'Spring_723.0': 'node_31097',
#  'Production Well_724.0': 'node_30655',
#  'Storage Tank_725.0': 'node_30655',
#  'Relift Station_726.0': 'node_32089',
#  'Production Well_727.0': 'node_31856',
#  'Production Well_728.0': 'node_31004',
#  'Storage Tank_729.0': 'node_32127',
#  'Storage Tank_730.0': 'node_8210',
#  'Storage Tank_731.0': 'node_7144',
#  'Pump Station_732.0': 'node_9755',
#  'Storage Tank_733.0': 'node_1969',
#  'Booster Station_734.0': 'node_2062',
#  'Storage Tank_735.0': 'node_104',
#  'Storage Tank_736.0': 'node_7618',
#  'Production Well_737.0': 'node_7709',
#  'Production Well_738.0': 'node_9825',
#  'Storage Tank_739.0': 'node_9825',
#  'Storage Tank_740.0': 'node_9825',
#  'Relift Station_741.0': 'node_8033',
#  'Storage Tank_742.0': 'node_8033',
#  'Storage Tank_743.0': 'node_9641',
#  'Relift Station_744.0': 'node_8164',
#  'Storage Tank_745.0': 'node_8164',
#  'Relift Station_746.0': 'node_7655',
#  'Storage Tank_747.0': 'node_9621',
#  'Storage Tank_748.0': 'node_7060',
#  'Storage Tank_749.0': 'node_8132',
#  'Storage Tank_750.0': 'node_7000',
#  'Storage Tank_751.0': 'node_9653',
#  'Storage Tank_752.0': 'node_9772',
#  'Storage Tank_753.0': 'node_7200',
#  'Storage Tank_755.0': 'node_9448',
#  'Storage Tank_757.0': 'node_7888',
#  'Storage Tank_758.0': 'node_7555',
#  'Storage Tank_759.0': 'node_8011',
#  'Storage Tank_760.0': 'node_7096',
#  'Storage Tank_761.0': 'node_9739',
#  'Storage Tank_762.0': 'node_8345',
#  'Booster Station_763.0': 'node_7430',
#  'Storage Tank_764.0': 'node_7430',
#  'Treatment Plant_765.0': 'node_7400',
#  'Relift Station_766.0': 'node_8182',
#  'Storage Tank_767.0': 'node_10223',
#  'Storage Tank_768.0': 'node_10223',
#  'Storage Tank_769.0': 'node_10223',
#  'Storage Tank_770.0': 'node_10094',
#  'Storage Tank_771.0': 'node_9385',
#  'Storage Tank_773.0': 'node_8784',
#  'Pump Station_774.0': 'node_7723',
#  'Storage Tank_775.0': 'node_7290',
#  'Storage Tank_776.0': 'node_7290',
#  'Relift Station_777.0': 'node_8773',
#  'Relift Station_778.0': 'node_9742',
#  'Storage Tank_779.0': 'node_9304',
#  'Storage Tank_780.0': 'node_8717',
#  'Production Well_781.0': 'node_30369',
#  'Production Well_782.0': 'node_30374',
#  'Production Well_783.0': 'node_30377',
#  'Treatment Plant_784.0': 'node_10213',
#  'Storage Tank_785.0': 'node_10213',
#  'Pump Station_786.0': 'node_6999',
#  'Storage Tank_787.0': 'node_6999',
#  'Storage Tank_788.0': 'node_9463',
#  'Storage Tank_789.0': 'node_4515',
#  'Storage Tank_790.0': 'node_5576',
#  'Storage Tank_791.0': 'node_4399',
#  'Storage Tank_792.0': 'node_4399',
#  'Pump Station_793.0': 'node_4681',
#  'Storage Tank_794.0': 'node_4573',
#  'Storage Tank_795.0': 'node_4573',
#  'Pump Station_796.0': 'node_5593',
#  'Relift Station_797.0': 'node_5593',
#  'Storage Tank_798.0': 'node_5602',
#  'Treatment Plant_799.0': 'node_5415',
#  'Production Well_800.0': 'node_5415',
#  'Storage Tank_801.0': 'node_5413',
#  'Intake_802.0': 'node_5413',
#  'Booster Station_803.0': 'node_5094',
#  'Reservoir_804.0': 'node_4365',
#  'Relift Station_805.0': 'node_5549',
#  'Storage Tank_806.0': 'node_5546',
#  'Pump Station_807.0': 'node_4607',
#  'Storage Tank_808.0': 'node_4607',
#  'Relift Station_809.0': 'node_4787',
#  'Reservoir_810.0': 'node_4778',
#  'Relift Station_811.0': 'node_4775',
#  'Storage Tank_812.0': 'node_4744',
#  'Relift Station_813.0': 'node_5026',
#  'Storage Tank_814.0': 'node_5532',
#  'Booster Station_815.0': 'node_5196',
#  'Relift Station_816.0': 'node_5216',
#  'Storage Tank_817.0': 'node_4679',
#  'Storage Tank_818.0': 'node_4571',
#  'Storage Tank_819.0': 'node_4991',
#  'Relift Station_820.0': 'node_4995',
#  'Storage Tank_821.0': 'node_4731',
#  'Relift Station_822.0': 'node_4470',
#  'Relift Station_823.0': 'node_4421',
#  'Storage Tank_824.0': 'node_4395',
#  'Relift Station_825.0': 'node_4444',
#  'Relift Station_826.0': 'node_4468',
#  'Storage Tank_827.0': 'node_4519',
#  'Storage Tank_828.0': 'node_4481',
#  'Storage Tank_829.0': 'node_4481',
#  'Pump Station_830.0': 'node_4403',
#  'Relift Station_831.0': 'node_5266',
#  'Relift Station_832.0': 'node_5284',
#  'Pump Station_833.0': 'node_4386',
#  'Storage Tank_835.0': 'node_43963',
#  'Storage Tank_836.0': 'node_44107',
#  'Storage Tank_838.0': 'node_44102',
#  'Storage Tank_841.0': 'node_43870',
#  'Storage Tank_842.0': 'node_43864',
#  'Relift Station_843.0': 'node_43390',
#  'Storage Tank_844.0': 'node_43390',
#  'Storage Tank_845.0': 'node_43745',
#  'Relift Station_846.0': 'node_44237',
#  'Pump Station_847.0': 'node_43893',
#  'Storage Tank_848.0': 'node_43910',
#  'Storage Tank_849.0': 'node_43884',
#  'Storage Tank_850.0': 'node_44149',
#  'Relift Station_851.0': 'node_44093',
#  'Filter Plant_853.0': 'node_43838',
#  'Treatment Plant_854.0': 'node_43884',
#  'Pump Station_855.0': 'node_38501',
#  'Spring_856.0': 'node_44200',
#  'Relift Station_857.0': 'node_44216',
#  'Storage Tank_858.0': 'node_44109',
#  'Reservoir_859.0': 'node_44130',
#  'Reservoir_860.0': 'node_44130',
#  'Storage Tank_861.0': 'node_43802',
#  'Production Well_862.0': 'node_44111',
#  'Production Well_863.0': 'node_44110',
#  'Filter Plant_864.0': 'node_43495',
#  'Pump Station_865.0': 'node_43775',
#  'Storage Tank_866.0': 'node_43774',
#  'Relift Station_867.0': 'node_43306',
#  'Storage Tank_868.0': 'node_43239',
#  'Storage Tank_869.0': 'node_43239',
#  'Pump Station_870.0': 'node_43234',
#  'Storage Tank_871.0': 'node_43234',
#  'Storage Tank_872.0': 'node_43371',
#  'Pump Station_873.0': 'node_43371',
#  'River Source_874.0': 'node_43502',
#  'Treatment Plant_875.0': 'node_43500',
#  'Reservoir_876.0': 'node_43208',
#  'Relift Station_877.0': 'node_43955',
#  'Storage Tank_878.0': 'node_43708',
#  'Storage Tank_879.0': 'node_43527',
#  'Pump Station_880.0': 'node_43529',
#  'River Source_881.0': 'node_43477',
#  'River Source_882.0': 'node_43477',
#  'Storage Tank_883.0': 'node_39843',
#  'Intake_884.0': 'node_39405',
#  'Relift Station_885.0': 'node_43992',
#  'Storage Tank_886.0': 'node_43425',
#  'Relift Station_887.0': 'node_43423',
#  'Storage Tank_888.0': 'node_43421',
#  'Intake_889.0': 'node_43421',
#  'Spring_890.0': 'node_43495',
#  'Storage Tank_893.0': 'node_34205',
#  'Production Well_894.0': 'node_33047',
#  'Storage Tank_895.0': 'node_33311',
#  'Production Well_896.0': 'node_33619',
#  'Relift Station_897.0': 'node_34119',
#  'Relift Station_898.0': 'node_34119',
#  'Relift Station_899.0': 'node_35972',
#  'Production Well_900.0': 'node_35882',
#  'Storage Tank_901.0': 'node_35383',
#  'Relift Station_902.0': 'node_35554',
#  'Relift Station_903.0': 'node_34715',
#  ...}

# %%
water_id
# Out:
# 'node_id'
